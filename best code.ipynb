# %% [markdown]
# # Code to Remember

# %% [markdown]
# ### Cleaning Data

# %%
#check for null
df.isna().sum()

#replace a specific value
df["column"] = df["column"].replace("\"N/A\"", np.nan)

#drop dupes
df = df.drop_duplicates()

#capitalize
df["colum"] = df["column"].str.strip().str.capitalize()

#check values
df["colum"].value_counts()
df["colum"].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #check for null
# ----> 2 df.isna().sum()
#       4 #replace a specific value
#       5 df["column"] = df["column"].replace("\"N/A\"", np.nan)
#
# NameError: name 'df' is not defined
