# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv("customers.csv")
orders = pd.read_csv("orders.csv")
order_items = pd.read_csv("order_items.csv")

# %%
customers["last_name"].str.strip().sort_values()
# Out:
# 12     Anderson
# 113    Anderson
# 81     Anderson
# 109    Anderson
# 4      Anderson
#          ...
# 68       Wilson
# 71       Wilson
# 95       Wilson
# 40       Wilson
# 59       Wilson
# Name: last_name, Length: 120, dtype: object

# %%
orders.sort_values("order_date", ascending = False)
# Out:
#      order_id  customer_id  order_date
# 213      5214         1075  2024-03-31
# 383      5384         1111  2024-03-31
# 215      5216         1103  2024-03-31
# 207      5208         1023  2024-03-30
# 14       5015         1019  2024-03-30
# ..        ...          ...         ...
# 430      5431         1006  2024-01-01
# 271      5272         1004  2024-01-01
# 56       5057         1019  2024-01-01
# 13       5014         1090  2024-01-01
# 246      5247         1017  2024-01-01
#
# [450 rows x 3 columns]

# %%
ny_customers = customers[customers["city"].str.strip().str.lower().isin(["new york", "nyc"])]
ny_customers.head()
# Out:
#     customer_id first_name last_name      city
# 0          1001       Evan     Smith  New York
# 3          1004      Aisha     Smith  new york
# 5          1006       Evan     Patel  new york
# 7          1008      Maria     Smith       NYC
# 10         1011        Ben     Davis  New York

# %%
# this is the code from above, its show ing you a table where all these values are true
customers["city"].str.strip().str.lower().isin(["new york", "nyc"])
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 115    False
# 116    False
# 117     True
# 118    False
# 119    False
# Name: city, Length: 120, dtype: bool

# %%
recent_orders = orders[orders["order_date"] > "2024-02-14"]
recent_orders.head()
# Out:
#     order_id  customer_id  order_date
# 1       5002         1045  2024-02-20
# 5       5006         1031  2024-03-10
# 7       5008         1061  2024-03-08
# 9       5010         1054  2024-03-24
# 12      5013         1074  2024-02-16

# %%
order_items[order_items["quantity"] >= 2].sort_values("quantity")
# Out:
#      order_id product_name  quantity  unit_price
# 870      5450      Monitor         2         300
# 26       5199      Monitor         2         300
# 22       5047        Mouse         2          25
# 17       5143      Monitor         2         300
# 16       5268    USB Cable         2          10
# ..        ...          ...       ...         ...
# 54       5108       Laptop         3        1200
# 42       5215    Desk Lamp         3          45
# 40       5328      Monitor         3         300
# 32       5391        Mouse         3          25
# 31       5250      Monitor         3         300
#
# [464 rows x 4 columns]

# %%
customers["first_name"] = customers["first_name"].str.strip().str.capitalize()
customers["last_name"] = customers["last_name"].str.strip().str.capitalize()

# %%
customers.sort_values("last_name")
# Out:
#      customer_id first_name last_name         city
# 12          1013      Priya  Anderson           LA
# 113         1114      Maria  Anderson           LA
# 81          1082     Jordan  Anderson      chicago
# 109         1110      Maria  Anderson           LA
# 4           1005      Priya  Anderson           LA
# ..           ...        ...       ...          ...
# 68          1069     Taylor    Wilson          NYC
# 71          1072     Taylor    Wilson           LA
# 95          1096        Zoe    Wilson  Los Angeles
# 40          1041       Evan    Wilson  Los Angeles
# 59          1060     Jordan    Wilson          NYC
#
# [120 rows x 4 columns]

# %%
#this will show unique names in a column
customers["city"].value_counts()
customers["city"].unique()
# Out:
# array(['New York', 'chicago', 'Los Angeles', 'new york', 'LA', 'NYC',
#        'Chicago'], dtype=object)

# %%
full_city_names = {'LA': 'Los Angeles', 'NYC': 'New York'}

# %%
customers["city"] = customers["city"].replace(full_city_names)

# %%
customers["city"] = customers["city"].str.title()

# %%
customers["city"].unique()
# Out:
# array(['New York', 'Chicago', 'Los Angeles'], dtype=object)

# %% [markdown]
# # Using.apply()

# %%
customers["clean_last_name"] = customers["last_name"].apply(
    lambda last_name:
    last_name.strip()
)

# %%
customers["clean_last_name"].value_counts()
# Out:
# clean_last_name
# Davis       19
# Smith       18
# Patel       17
# Brown       16
# Chen        16
# Anderson    13
# Wilson      13
# Lopez        8
# Name: count, dtype: int64

# %%
order_items["total_price"] = order_items["quantity"] * order_items["unit_price"]

# %%
order_items["total_price_apply"] = order_items.apply(
    lambda row:
    row["quantity"] * row["unit_price"], axis = 1
)

# %%
order_items
# Out:
#      order_id product_name  quantity  unit_price  total_price  \
# 0        5311      Monitor         3         300          900
# 1        5303     Keyboard         3          70          210
# 2        5012     Keyboard         3          70          210
# 3        5318      Monitor         3         300          900
# 4        5080    USB Cable         1          10           10
# ..        ...          ...       ...         ...          ...
# 895      5303    USB Cable         2          10           20
# 896      5117      Monitor         2         300          600
# 897      5124     Keyboard         1          70           70
# 898      5399    USB Cable         2          10           20
# 899      5281      Monitor         1         300          300
#
#      total_price_apply
# 0                  900
# 1                  210
# 2                  210
# 3                  900
# 4                   10
# ..                 ...
# 895                 20
# 896                600
# 897                 70
# 898                 20
# 899                300
#
# [900 rows x 6 columns]

# %%
order_items["order_types"] = order_items.apply(
    lambda row: (
        "Large Expensive Order" if row["quantity"] >= 3 and row["unit_price"] > 50
        else "Bulk Order" if row["quantity"] >= 3
        else "Standard Order"
    ), axis = 1
)

# %%
order_items
# Out:
#      order_id product_name  quantity  unit_price  total_price  \
# 0        5311      Monitor         3         300          900
# 1        5303     Keyboard         3          70          210
# 2        5012     Keyboard         3          70          210
# 3        5318      Monitor         3         300          900
# 4        5080    USB Cable         1          10           10
# ..        ...          ...       ...         ...          ...
# 895      5303    USB Cable         2          10           20
# 896      5117      Monitor         2         300          600
# 897      5124     Keyboard         1          70           70
# 898      5399    USB Cable         2          10           20
# 899      5281      Monitor         1         300          300
#
#      total_price_apply            order_types
# 0                  900  Large Expensive Order
# 1                  210  Large Expensive Order
# 2                  210  Large Expensive Order
# 3                  900  Large Expensive Order
# 4                   10         Standard Order
# ..                 ...                    ...
# 895                 20         Standard Order
# 896                600         Standard Order
# 897                 70         Standard Order
# 898                 20         Standard Order
# 899                300         Standard Order
#
# [900 rows x 7 columns]

# %% [markdown]
# # Merging Tables

# %%
orders_with_customers = orders.merge(customers, how="inner")
orders_with_customers.head()
# Out:
#    order_id  customer_id  order_date first_name last_name         city  \
# 0      5001         1089  2024-01-26      Aisha     Smith     New York
# 1      5002         1045  2024-02-20      Priya     Davis     New York
# 2      5003         1004  2024-02-14      Aisha     Smith     New York
# 3      5004         1036  2024-02-13      Chloe     Davis     New York
# 4      5005         1070  2024-01-05     Jordan     Brown  Los Angeles
#
#   clean_last_name
# 0           Smith
# 1           Davis
# 2           Smith
# 3           Davis
# 4           Brown

# %%
orders_customers_items = orders_with_customers.merge(order_items, on = "order_id", how="inner")

# %%
orders_customers_items
# Out:
#      order_id  customer_id  order_date first_name last_name      city  \
# 0        5001         1089  2024-01-26      Aisha     Smith  New York
# 1        5001         1089  2024-01-26      Aisha     Smith  New York
# 2        5001         1089  2024-01-26      Aisha     Smith  New York
# 3        5002         1045  2024-02-20      Priya     Davis  New York
# 4        5002         1045  2024-02-20      Priya     Davis  New York
# ..        ...          ...         ...        ...       ...       ...
# 895      5450         1008  2024-02-26      Maria     Smith  New York
# 896      5450         1008  2024-02-26      Maria     Smith  New York
# 897      5450         1008  2024-02-26      Maria     Smith  New York
# 898      5450         1008  2024-02-26      Maria     Smith  New York
# 899      5450         1008  2024-02-26      Maria     Smith  New York
#
#     clean_last_name product_name  quantity  unit_price  total_price  \
# 0             Smith      Monitor         1         300          300
# 1             Smith    Desk Lamp         2          45           90
# 2             Smith    Desk Lamp         1          45           45
# 3             Davis      Monitor         2         300          600
# 4             Davis      Monitor         2         300          600
# ..              ...          ...       ...         ...          ...
# 895           Smith       Laptop         2        1200         2400
# 896           Smith     Keyboard         3          70          210
# 897           Smith    USB Cable         2          10           20
# 898           Smith        Mouse         3          25           75
# 899           Smith      Monitor         2         300          600
#
#      total_price_apply            order_types
# 0                  300         Standard Order
# 1                   90         Standard Order
# 2                   45         Standard Order
# 3                  600         Standard Order
# 4                  600         Standard Order
# ..                 ...                    ...
# 895               2400         Standard Order
# 896                210  Large Expensive Order
# 897                 20         Standard Order
# 898                 75             Bulk Order
# 899                600         Standard Order
#
# [900 rows x 13 columns]

# %%
combined = (
    orders.merge(customers, on="customer_id", how="inner").merge(order_items, on="order_id", how="inner")
    
)
combined.head()
# Out:
#    order_id  customer_id  order_date first_name last_name      city  \
# 0      5001         1089  2024-01-26      Aisha     Smith  New York
# 1      5001         1089  2024-01-26      Aisha     Smith  New York
# 2      5001         1089  2024-01-26      Aisha     Smith  New York
# 3      5002         1045  2024-02-20      Priya     Davis  New York
# 4      5002         1045  2024-02-20      Priya     Davis  New York
#
#   clean_last_name product_name  quantity  unit_price  total_price  \
# 0           Smith      Monitor         1         300          300
# 1           Smith    Desk Lamp         2          45           90
# 2           Smith    Desk Lamp         1          45           45
# 3           Davis      Monitor         2         300          600
# 4           Davis      Monitor         2         300          600
#
#    total_price_apply     order_types
# 0                300  Standard Order
# 1                 90  Standard Order
# 2                 45  Standard Order
# 3                600  Standard Order
# 4                600  Standard Order

# %% [markdown]
# # Grouping and Aggregation

# %%
order_items["total_price"].sum()
# Out:
# np.int64(420615)

# %%
order_items.groupby("product_name")["total_price"].sum().sort_values(ascending=False)
# Out:
# product_name
# Laptop       296400
# Monitor       90000
# Keyboard      14140
# Desk Lamp     10755
# Mouse          6750
# USB Cable      2570
# Name: total_price, dtype: int64

# %%
order_items.groupby("product_name")["quantity"].sum().sort_values(ascending=False)
# Out:
# product_name
# Monitor      300
# Mouse        270
# USB Cable    257
# Laptop       247
# Desk Lamp    239
# Keyboard     202
# Name: quantity, dtype: int64

# %%
# do multiple computations with the AG method
order_items.groupby("product_name").agg(
    total_revenue=("total_price", "sum"),
    avg_quantity=("quantity", "mean")
)
# Out:
#               total_revenue  avg_quantity
# product_name
# Desk Lamp             10755      1.593333
# Keyboard              14140      1.578125
# Laptop               296400      1.776978
# Monitor               90000      1.754386
# Mouse                  6750      1.719745
# USB Cable              2570      1.658065

# %%
#combined.groupby("customer_id")["total_price"].sum().head()
combined.groupby("customer_id")["total_price"].sum().sort_values(ascending=False).head()
# Out:
# customer_id
# 1008    13625
# 1057    13330
# 1087    11170
# 1061    10645
# 1070     9945
# Name: total_price, dtype: int64

# %% [markdown]
# # Reshaping Data

# %%
sample = combined[["customer_id", "product_name", "total_price"]].head(12)

# %%
pivot = sample.pivot_table(index="customer_id", columns="product_name", values="total_price", aggfunc="sum")

# %%
pivot
# Out:
# product_name  Desk Lamp  Keyboard  Laptop  Monitor  Mouse  USB Cable
# customer_id
# 1004              135.0     140.0  2400.0      NaN    NaN       20.0
# 1036                NaN       NaN     NaN      NaN   50.0       20.0
# 1045                NaN       NaN     NaN   1200.0    NaN        NaN
# 1089              135.0       NaN     NaN    300.0    NaN        NaN

# %%
pivot.reset_index().melt(
    id_vars="customer_id",
    var_name="product",
    value_name="revenue"
)
# Out:
#     customer_id    product  revenue
# 0          1004  Desk Lamp    135.0
# 1          1036  Desk Lamp      NaN
# 2          1045  Desk Lamp      NaN
# 3          1089  Desk Lamp    135.0
# 4          1004   Keyboard    140.0
# 5          1036   Keyboard      NaN
# 6          1045   Keyboard      NaN
# 7          1089   Keyboard      NaN
# 8          1004     Laptop   2400.0
# 9          1036     Laptop      NaN
# 10         1045     Laptop      NaN
# 11         1089     Laptop      NaN
# 12         1004    Monitor      NaN
# 13         1036    Monitor      NaN
# 14         1045    Monitor   1200.0
# 15         1089    Monitor    300.0
# 16         1004      Mouse      NaN
# 17         1036      Mouse     50.0
# 18         1045      Mouse      NaN
# 19         1089      Mouse      NaN
# 20         1004  USB Cable     20.0
# 21         1036  USB Cable     20.0
# 22         1045  USB Cable      NaN
# 23         1089  USB Cable      NaN

# %%
combined.query("quantity >= 2").groupby("city").agg(total_revenue=("total_price", "sum")).sort_values("total_revenue", ascending=False)
# Out:
#              total_revenue
# city
# New York            131450
# Los Angeles          98180
# Chicago              85750

# %%
combined
# Out:
#      order_id  customer_id  order_date first_name last_name      city  \
# 0        5001         1089  2024-01-26      Aisha     Smith  New York
# 1        5001         1089  2024-01-26      Aisha     Smith  New York
# 2        5001         1089  2024-01-26      Aisha     Smith  New York
# 3        5002         1045  2024-02-20      Priya     Davis  New York
# 4        5002         1045  2024-02-20      Priya     Davis  New York
# ..        ...          ...         ...        ...       ...       ...
# 895      5450         1008  2024-02-26      Maria     Smith  New York
# 896      5450         1008  2024-02-26      Maria     Smith  New York
# 897      5450         1008  2024-02-26      Maria     Smith  New York
# 898      5450         1008  2024-02-26      Maria     Smith  New York
# 899      5450         1008  2024-02-26      Maria     Smith  New York
#
#     clean_last_name product_name  quantity  unit_price  total_price  \
# 0             Smith      Monitor         1         300          300
# 1             Smith    Desk Lamp         2          45           90
# 2             Smith    Desk Lamp         1          45           45
# 3             Davis      Monitor         2         300          600
# 4             Davis      Monitor         2         300          600
# ..              ...          ...       ...         ...          ...
# 895           Smith       Laptop         2        1200         2400
# 896           Smith     Keyboard         3          70          210
# 897           Smith    USB Cable         2          10           20
# 898           Smith        Mouse         3          25           75
# 899           Smith      Monitor         2         300          600
#
#      total_price_apply            order_types
# 0                  300         Standard Order
# 1                   90         Standard Order
# 2                   45         Standard Order
# 3                  600         Standard Order
# 4                  600         Standard Order
# ..                 ...                    ...
# 895               2400         Standard Order
# 896                210  Large Expensive Order
# 897                 20         Standard Order
# 898                 75             Bulk Order
# 899                600         Standard Order
#
# [900 rows x 13 columns]
