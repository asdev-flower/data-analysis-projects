# %% [markdown]
# Cleaning Data Demos

# %%
import pandas as pd
import numpy as np

# %%
students = pd.read_csv("student_records_dirty.csv")

# %%
students.head()
# Out:
#    student_id first_name last_name  age             major enrollment_date  \
# 0       17270     Taylor      Chen   23              Bio        2/28/2024
# 1       10860     Olivia  Martinez   73  Computer Science       30-Jan-24
# 2       15390      Priya    Garcia   52               bio       2/10/2024
# 3       15191      Priya  Anderson   61                CS        2/8/2024
# 4       15734       Noah    Wilson   36          Comp Sci        8-Feb-24
#
#   course_grade  gpa  tuition_paid
# 0           12  3.8      17548.10
# 1           12  2.7      13129.13
# 2           95  1.9      19051.36
# 3            3  2.0      17242.61
# 4          -20  3.2           NaN

# %%
#completely random info every time you roll
students.sample(5)
# Out:
#      student_id first_name last_name  age             major enrollment_date  \
# 255       14199       Alex     Patel   43           Biology        3/7/2024
# 291       17022       Evan  Anderson   69              Bio        5/24/2024
# 337       10784        Ben  Anderson   26               bio       20-Apr-24
# 49        17099       Noah     Smith   25  Computer Science       17-Feb-24
# 97        15892      Aisha     Lopez   49              BIO        12-Feb-24
#
#     course_grade  gpa  tuition_paid
# 255           95  3.8      21642.70
# 291           12  3.8      18882.82
# 337      ninety   1.9      19474.87
# 49            52  2.0      21412.00
# 97             0  NaN      19281.17

# %%
students.isna().sum()
# Out:
# student_id          0
# first_name          0
# last_name           0
# age                 0
# major               0
# enrollment_date     0
# course_grade       29
# gpa                94
# tuition_paid       21
# dtype: int64

# %%
students["course_grade"] = students["course_grade"].replace("\"N/A\"", np.nan)

# %%
students["course_grade"].value_counts(dropna=False)
# Out:
# course_grade
# 100         36
# 12          34
# NaN         32
#  ninety     32
# 95          27
# -20         27
# 0           27
# 52          25
# 64          25
# 85          25
# 88          24
# 3           22
# 76          19
# Name: count, dtype: int64

# %%
students = students.drop_duplicates()

# %%
students.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 345    False
# 346    False
# 347    False
# 348    False
# 349    False
# Length: 350, dtype: bool

# %%
students["major"] = students["major"].str.strip().str.capitalize()

students["major"] = students["major"].replace({
    "Comp sci" : "Computer science",
    "Cs" : "Computer science",
    "Computer science" : "Computer Science",
    "Bio" : "Biology",
    "Psych" : "Psychology"
})

# %%
students["major"].value_counts()
# Out:
# major
# Biology             117
# Psychology          115
# Computer science     68
# Computer Science     50
# Name: count, dtype: int64

# %%
students["course_grade"].value_counts()
# Out:
# course_grade
# 100         36
# 12          34
#  ninety     31
# 0           27
# 95          26
# -20         26
# 64          25
# 52          25
# 85          24
# 88          24
# 3           21
# 76          19
# Name: count, dtype: int64

# %%
students["course_grade"] = students["course_grade"].str.strip()
students.loc[students["course_grade"] == "ninety", "course_grade"] = 90

# %%
students["course_grade"].value_counts()
# Out:
# course_grade
# 100    36
# 12     34
# 90     31
# 0      27
# 95     26
# -20    26
# 64     25
# 52     25
# 85     24
# 88     24
# 3      21
# 76     19
# Name: count, dtype: int64

# %%
students["age"].value_counts(dropna=False)
# Out:
# age
#  74    12
#  32    11
#  33     9
#  85     9
#  79     8
#        ..
#  87     2
# -12     2
#  47     2
#  57     1
#  27     1
# Name: count, Length: 75, dtype: int64

# %%
students.loc[students["age"] < 0, "age"] = np.nan
students.loc[students["age"] > 110, "age"] = np.nan

# %%
students['age'].describe()
# Out:
# count    345.000000
# mean      52.617391
# std       20.951321
# min       17.000000
# 25%       33.000000
# 50%       52.000000
# 75%       71.000000
# max       89.000000
# Name: age, dtype: float64

# %%
#create a columnb combining first and last names
students["full_name"] = students["last_name"] + ', ' + students["first_name"]
students.head()
# Out:
#    student_id first_name last_name   age             major enrollment_date  \
# 0       17270     Taylor      Chen  23.0           Biology       2/28/2024
# 1       10860     Olivia  Martinez  73.0  Computer Science       30-Jan-24
# 2       15390      Priya    Garcia  52.0           Biology       2/10/2024
# 3       15191      Priya  Anderson  61.0  Computer science        2/8/2024
# 4       15734       Noah    Wilson  36.0  Computer science        8-Feb-24
#
#   course_grade  gpa  tuition_paid         full_name
# 0           12  3.8      17548.10      Chen, Taylor
# 1           12  2.7      13129.13  Martinez, Olivia
# 2           95  1.9      19051.36     Garcia, Priya
# 3            3  2.0      17242.61   Anderson, Priya
# 4          -20  3.2           NaN      Wilson, Noah

# %%
students["age_group"] = pd.cut(
    students["age"],
    bins=[0, 25, 65, 120],
    labels=["Young Adults", "Working Adults", "Retired"],
)

# %%
students[["age", "age_group"]].value_counts(dropna=False)
# Out:
# age   age_group
# 74.0  Retired           12
# 32.0  Working Adults    11
# 33.0  Working Adults     9
# 85.0  Retired            9
# 79.0  Retired            8
#                         ..
# 64.0  Working Adults     2
# 86.0  Retired            2
# 87.0  Retired            2
# 57.0  Working Adults     1
# 27.0  Working Adults     1
# Name: count, Length: 74, dtype: int64

# %%
students["enrollment_date"] = pd.to_datetime(students["enrollment_date"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 students["enrollment_date"] = pd.to_datetime(students["enrollment_date"])
#
# File c:\Users\Andres\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\Andres\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File c:\Users\Andres\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\tools\datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)    464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "30-Jan-24" doesn't match format "%m/%d/%Y", at position 1. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
