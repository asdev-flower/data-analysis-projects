# %% [markdown]
# Loops: how to tell python to do something over and over again in a sequence

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('order_data.csv')

# %%
df.head()
# Out:
#    order_id  customer_id     region  category  quantity  unit_price  returned  \
# 0         1         1102       West      Home         5           8      True
# 1         2         1051  Northeast      Home         4           8     False
# 2         3         1092      South  Clothing         5           8      True
# 3         4         1014    Midwest  Clothing         5         120     False
# 4         5         1106       West      Home         1           8     False
#
#    order_date  revenue
# 0  2024-01-11       40
# 1  2024-01-15       32
# 2  2024-02-04       40
# 3  2024-02-02      600
# 4  2024-03-24        8

# %%
for i in range(5):
    print ("i is:", i)
# Out:
# i is: 0
# i is: 1
# i is: 2
# i is: 3
# i is: 4
